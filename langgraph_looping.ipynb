# %% [markdown]
# <a href="https://colab.research.google.com/github/smagara/LangGraph-Coursework/blob/main/langgraph_looping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 🛠️ LangGraph course assignment Looping Graph:
#   - Implement looping logic to route the flow back to the nodes
#   - Create a single conditional edge to handle decision-making and control graph flow
#   - Main goal:
#     - Coding up looping logic

# %%
#installs
# %pip install -U langgraph
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.4/152.4 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 kB 15.8 MB/s eta 0:00:00
# ...

# %%
# setup imports
from langgraph.graph import StateGraph, END, START
from typing import TypedDict
from IPython.display import display, Image

# %%
# state object
class State(TypedDict):
    name: str
    description: str
